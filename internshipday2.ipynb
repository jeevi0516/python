# %%
# List

name = ["jeevi", "pavaki", "nila"]
name.append("zaara")

marks = [78, 90, 80]

print(name)
print(marks[2])

print(len(name))
print(len(marks))


# Tuple

days = ("Monday", "Tuesday", "Wednesday", "Thrusday","Friday" ,"Saturday")
print(days[4])



# Dictionary

student = {
    "name": "jeevii",
    "age": 21
}
# Out:
# ['jeevi', 'pavaki', 'nila', 'zaara']
# 80
# 4
# 3
# Friday
