# %%
import pandas as pd
df=pd.read_csv("project_data.csv")
df.head(15)
# Out:
#    Student_ID  Computer_Science  Attendance  Study_Hours_Per_Week  \
# 0     STU0001                50          98                    26
# 1     STU0002                60          88                    12
# 2     STU0003                52          74                    26
# 3     STU0004                93          67                    13
# 4     STU0005                89          80                    40
# 5     STU0006                87          98                    18
# 6     STU0007                64          78                    25
# 7     STU0008                75          82                    33
# 8     STU0009                82          70                    40
# 9     STU0010                39          70                    12
# 10    STU0011                82          83                    36
# 11    STU0012                52          95                     4
# 12    STU0013                59          99                     5
# ...

# %%
df.tail(10)
# Out:
#     Student_ID  Computer_Science  Attendance  Study_Hours_Per_Week  \
# 990    STU0991                53          86                    32
# 991    STU0992                40          64                    11
# 992    STU0993                75          79                    10
# 993    STU0994                72          70                     9
# 994    STU0995                65          69                    14
# 995    STU0996                63          99                    13
# 996    STU0997                78          97                    25
# 997    STU0998                65          65                     2
# 998    STU0999                92          67                    35
# 999    STU1000                62          82                     7
#
#      Assignment_Score  Internal_Marks  Total_Marks  Average_Marks Grade  \
# 990                55              63          171          57.00     D
# 991                42              54          136          45.33     F
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Student_ID            1000 non-null   object
#  1   Computer_Science      1000 non-null   int64
#  2   Attendance            1000 non-null   int64
#  3   Study_Hours_Per_Week  1000 non-null   int64
#  4   Assignment_Score      1000 non-null   int64
#  5   Internal_Marks        1000 non-null   int64
#  6   Total_Marks           1000 non-null   int64
#  7   Average_Marks         1000 non-null   float64
#  8   Grade                 1000 non-null   object
#  9   Result                1000 non-null   object
#  10  Rank                  1000 non-null   int64
# dtypes: float64(1), int64(7), object(3)
# memory usage: 86.1+ KB

# %%
df.columns
# Out:
# Index(['Student_ID', 'Computer_Science', 'Attendance', 'Study_Hours_Per_Week',
#        'Assignment_Score', 'Internal_Marks', 'Total_Marks', 'Average_Marks',
#        'Grade', 'Result', 'Rank'],
#       dtype='object')

# %%
df.describe
# Out:
# <bound method NDFrame.describe of     Student_ID  Computer_Science  Attendance  Study_Hours_Per_Week  \
# 0      STU0001                50          98                    26
# 1      STU0002                60          88                    12
# 2      STU0003                52          74                    26
# 3      STU0004                93          67                    13
# 4      STU0005                89          80                    40
# ..         ...               ...         ...                   ...
# 995    STU0996                63          99                    13
# 996    STU0997                78          97                    25
# 997    STU0998                65          65                     2
# 998    STU0999                92          67                    35
# 999    STU1000                62          82                     7
#
#      Assignment_Score  Internal_Marks  Total_Marks  Average_Marks Grade  \
# ...
